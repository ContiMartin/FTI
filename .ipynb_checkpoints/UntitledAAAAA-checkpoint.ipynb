# %%
GRAMMAR = '''
    @@grammar::CALC


    start = expression $ ;


    expression
        =
        | expression '+' term
        | expression '-' term
        | term
        ;


    term
        =
        | term '*' factor
        | term '/' factor
        | factor
        ;


    factor
        =
        | '(' expression ')'
        | number
        ;


    number = /\d+/ ;
'''


if __name__ == '__main__':
    import pprint
    import json
    from tatsu import parse
    from tatsu.util import asjson

    ast = parse(GRAMMAR, '3 + 5 * ( 10 - 20 )')
    print('# PPRINT')
    pprint.pprint(ast, indent=2, width=20)
    print()

    print('# JSON')
    print(json.dumps(asjson(ast), indent=2))
    print()
# Out:
# # PPRINT
# [ '3',
#   '+',
#   [ '5',
#     '*',
#     [ '(',
#       [ '10',
#         '-',
#         '20'],
#       ')']]]
#
# # JSON
# [
#   "3",
#   "+",
#   [
#     "5",
#     "*",
#     [
#       "(",
#       [
#         "10",
#         "-",
#         "20"
#       ],
#       ")"
#     ]
#   ]
# ]

# %%
<IF> -- if <condicion> { <BLOQUES> <S> 
<S> -- } | } <ELSEIF>
<ELSEIF> -- <CONDICION> | { <BLOQUES> } <ELSEIF> | ELSE | { <BLOQUES> }
<CONDICION> -- <CONDICION> | <VAR>
<VAR> -- ( <VAR> <OPE-ARIT> <VAR>) | <VAR> <OPE-COND> <VAR>| unNumero
<OPE-ARIT> -- + | - | | | | |
<OPE-COND> -- 
<BLOQUE> -- IF | WHILE
<WAHILE> while <CONDICION> { <BLOQUE> }

# %%
GRAMMAR = '''
    @@grammar::CALC


    START = BLOQUE $ ;


    IF = 'if' CONDICION '{' BLOQUE;

    S
        =
        | '}'
        | '}' ELSEIF
        ;
        
    ELSEIF
        =
        | 'elseif' CONDICION '{' BLOQUE ELSEIF
        | 'else' '{' BLOQUE 
        ;
        
    BLOQUE
        =
        | instruccion ';' BLOQUE
        | IF
        | WHILE
        | S
        ;

    CONDICION
        =
        | CONDICION
        | VAR
        ;

    VAR
        =
        | '(' VAR OPE_ARIT VAR ')'
        | '(' VAR OPE_COND VAR ')'
        | number
        ;
        
    OPE_ARIT
        =
        | '+' 
        | '-' 
        | '*' 
        | '%' 
        | '/'
        ;
        
    OPE_COND
        =
        | '<='
        | '>='
        | '=='
        | '<'
        | '>'
        | '!='
        | '||'
        ;
        
    WHILE = 'while' CONDICION '{' BLOQUE ;
        
    instruccion =/[0-9a-zA-Z-_ .]{1,100}/ ;  
    number = /\d+/ ;
'''


if __name__ == '__main__':
    import pprint
    import json
    from tatsu import parse
    from tatsu.util import asjson

    ast = parse(GRAMMAR, 'if ( 5 + 3 ) { if (3>4){tttt}}')

    
    print('# PPRINT')
    pprint.pprint(ast, indent=5, width=20)
    print()

    print('# JSON')
    print(json.dumps(asjson(ast), indent=2))
#     print()
# Out:
# ---------------------------------------------------------------------------
# FailedParse                               Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\tatsu\contexts.py in parse(self, text, rule_name, filename, buffer_class, semantics, trace, whitespace, **kwargs)
#     202             rule = self._find_rule(rule_name)
# --> 203             result = rule()
#     204             self.ast[rule_name] = result
#
# ~\Anaconda3\lib\site-packages\tatsu\grammars.py in parse(self, ctx)
#     693     def parse(self, ctx):
# --> 694         result = self._parse_rhs(ctx, self.exp)
#     695         if self.is_name:
#
# ~\Anaconda3\lib\site-packages\tatsu\grammars.py in _parse_rhs(self, ctx, exp)
#     700         ruleinfo = RuleInfo(self.name, exp.parse, self.params, self.kwparams)
# --> 701         result = ctx._call(ruleinfo)
#     702         if isinstance(result, AST):
#
# ~\Anaconda3\lib\site-packages\tatsu\contexts.py in _call(self, ruleinfo)
#     508
# ...

# %%
>>> from sklearn.datasets import load_iris
>>> from sklearn.model_selection import cross_val_score
>>> from sklearn.tree import DecisionTreeClassifier
>>> clf = DecisionTreeClassifier(random_state=0)
>>> iris = load_iris()
>>> cross_val_score(clf, iris.data, iris.target, cv=10)
...                             
...
array([ 1.     ,  0.93...,  0.86...,  0.93...,  0.93...,
        0.93...,  0.93...,  1.     ,  0.93...,  1.      ])
# Out:
#   File "<ipython-input-2-7c47932f1fe8>", line 9
#     array([ 1.     ,  0.93...,  0.86...,  0.93...,  0.93...,
#                             ^
# SyntaxError: invalid syntax

# %%
ast = parse(GRAMMAR, 'if ( 5 + 3 ) { while (5 < 3) { if ( 5 + 3 ) { }}}')
ast = parse(GRAMMAR, 'if ( 5 + 3 ) {.}')

# %%
# hello.py - http://www.graphviz.org/content/hello

from graphviz import Digraph

g = Digraph('G', filename='hello.gv')

g.edge('Hello', 'World')

g.view()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\graphviz\backend.py in run(cmd, input, capture_output, check, quiet, **kwargs)
#     146     try:
# --> 147         proc = subprocess.Popen(cmd, startupinfo=get_startupinfo(), **kwargs)
#     148     except OSError as e:
#
# ~\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     755                                 errread, errwrite,
# --> 756                                 restore_signals, start_new_session)
#     757         except:
#
# ...
